# %%
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random,os

# %% [markdown]
# # Define Constants

# %%
FAST_RUN = False
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %% [markdown]
# # Prepare Traning Data

# %%
len(os.listdir('training')),len(os.listdir('testing'))
# Out:
# (1000, 200)

# %%
filenames = os.listdir("training")
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'cat':
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df.head()
# Out:
#        filename  category
# 0  cat.4015.jpg         1
# 1  cat.4004.jpg         1
# 2  cat.4017.jpg         1
# 3  cat.4003.jpg         1
# 4  cat.4023.jpg         1

# %%
df.tail()
# Out:
#          filename  category
# 995  dog.4185.jpg         0
# 996  dog.4352.jpg         0
# 997  dog.4342.jpg         0
# 998  dog.4274.jpg         0
# 999  dog.4339.jpg         0

# %%
df[df['category']==1]
# Out:
#          filename  category
# 0    cat.4001.jpg         1
# 1    cat.4002.jpg         1
# 2    cat.4003.jpg         1
# 3    cat.4004.jpg         1
# 4    cat.4005.jpg         1
# ..            ...       ...
# 495  cat.4490.jpg         1
# 496  cat.4491.jpg         1
# 497  cat.4492.jpg         1
# 498  cat.4493.jpg         1
# 499  cat.4494.jpg         1
#
# [500 rows x 2 columns]

# %%
df['category'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
len([i for i in df['filename'].tolist() if 'cat' in i]) , len([i for i in df['filename'].tolist() if 'dog' in i])
# Out:
# (500, 500)

# %% [markdown]
# ### See Total In count

# %%
df['category'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='category'>

# %% [markdown]
# From our data we have 12000 cats and 12000 dogs

# %% [markdown]
# # See sample image

# %%
sample = random.choice(filenames)
image = load_img("training/"+sample)
plt.imshow(image)

# %%
sample = random.choice(filenames)
sample
# Out:
# 'cat.4093.jpg'

# %%
filenames[490:510]
# Out:
# ['cat.4485.jpg',
#  'cat.4486.jpg',
#  'cat.4487.jpg',
#  'cat.4488.jpg',
#  'cat.4489.jpg',
#  'cat.4490.jpg',
#  'cat.4491.jpg',
#  'cat.4492.jpg',
#  'cat.4493.jpg',
#  'cat.4494.jpg',
#  'dog.4001.jpg',
#  'dog.4002.jpg',
#  'dog.4003.jpg',
#  'dog.4004.jpg',
#  'dog.4005.jpg',
#  'dog.4006.jpg',
#  'dog.4007.jpg',
#  'dog.4008.jpg',
#  'dog.4009.jpg',
#  'dog.4010.jpg']

# %% [markdown]
# # Build Model
#
# <img src="https://i.imgur.com/ebkMGGu.jpg" width="100%"/>

# %% [markdown]
# * **Input Layer**: It represent input image data. It will reshape image into single diminsion array. Example your image is 64x64 = 4096, it will convert to (4096,1) array.
# * **Conv Layer**: This layer will extract features from image.
# * **Pooling Layer**: This layerreduce the spatial volume of input image after convolution.
# * **Fully Connected Layer**: It connect the network from a layer to another layer
# * **Output Layer**: It is the predicted values layer.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
# 63*63*32
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
# 30*30*64
# model.add(Conv2D(128, (3, 3), activation='relu'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
# 14*14*128
model.add(Flatten())
model.add(Dense(512, activation='tanh'))
model.add(Dense(64, activation='sigmoid'))
model.add(Dense(2, activation='softmax'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  batch_normalization (Batch  (None, 126, 126, 32)      128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 63, 63, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  batch_normalization_1 (Bat  (None, 61, 61, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 57600)             0
#
#  dense (Dense)               (None, 512)               29491712
#
#  dense_1 (Dense)             (None, 64)                32832
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 29544450 (112.70 MB)
# Trainable params: 29544258 (112.70 MB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Callbacks

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# **Early Stop**
#
# To prevent over fitting we will stop the learning after 10 epochs and val_loss value not decreased

# %%
earlystop = EarlyStopping(patience=10)

# %% [markdown]
# **Learning Rate Reduction**
#
# We will reduce the learning rate when then accuracy not increase for 2 steps

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc',
                                            patience=2,
                                            verbose=1,
                                            factor=0.5,
                                            min_lr=0.00001)

# 0.01
# 0.005
# 0.01
# 0.005
# 0.0025
# 0.000125
# 0.0000000001

# %%
callbacks = [earlystop, learning_rate_reduction]

# %% [markdown]
# # Prepare data

# %% [markdown]
# Because we will use image genaretor `with class_mode="categorical"`. We need to convert column category into string. Then imagenerator will convert it one-hot encoding which is good for our classification.
#
# So we will convert 1 to dog and 0 to cat

# %%
df["category"] = df["category"].replace({1: 'cat', 0: 'dog'})

# %%
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
validate_df['category'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size=15

# %% [markdown]
# # Traning Generator

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# %%
train_df
# Out:
#             filename category
# 0       cat.4028.jpg      cat
# 1       dog.4052.jpg      dog
# 2    dog.4205(1).jpg      dog
# 3       dog.4008.jpg      dog
# 4       dog.4208.jpg      dog
# ..               ...      ...
# 795     cat.4132.jpg      cat
# 796     cat.4258.jpg      cat
# 797     dog.4388.jpg      dog
# 798     cat.4471.jpg      cat
# 799     cat.4075.jpg      cat
#
# [800 rows x 2 columns]

# %%
train_generator = train_datagen.flow_from_dataframe(
    train_df,
    "/content/drive/MyDrive/Data/CNN/training",
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 800 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Validation Generator

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df,
    "/content/drive/MyDrive/Data/CNN/training",
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 200 validated image filenames belonging to 2 classes.

# %% [markdown]
# # See how our generator work

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df,
    "/content/drive/MyDrive/Data/CNN/training",
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# Seem to be nice

# %% [markdown]
# # Fit Model

# %%
import warnings
from warnings import filterwarnings
filterwarnings('ignore')

# %%
epochs=20
history = model.fit_generator(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 53/53 [==============================] - ETA: 0s - loss: 0.7086 - accuracy: 0.5605
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 61s 1s/step - loss: 0.7086 - accuracy: 0.5605 - val_loss: 0.8337 - val_accuracy: 0.5282 - lr: 0.0010
# Epoch 2/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6738 - accuracy: 0.5911
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 55s 1s/step - loss: 0.6738 - accuracy: 0.5911 - val_loss: 0.7558 - val_accuracy: 0.5385 - lr: 0.0010
# Epoch 3/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6715 - accuracy: 0.5885
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 57s 1s/step - loss: 0.6715 - accuracy: 0.5885 - val_loss: 0.7463 - val_accuracy: 0.5282 - lr: 0.0010
# Epoch 4/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6523 - accuracy: 0.6229
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 57s 1s/step - loss: 0.6523 - accuracy: 0.6229 - val_loss: 0.8079 - val_accuracy: 0.5282 - lr: 0.0010
# Epoch 5/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6479 - accuracy: 0.6025
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 54s 1s/step - loss: 0.6479 - accuracy: 0.6025 - val_loss: 0.7811 - val_accuracy: 0.5385 - lr: 0.0010
# Epoch 6/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6568 - accuracy: 0.6089
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 57s 1s/step - loss: 0.6568 - accuracy: 0.6089 - val_loss: 0.6860 - val_accuracy: 0.5641 - lr: 0.0010
# Epoch 7/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6516 - accuracy: 0.6038
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 55s 1s/step - loss: 0.6516 - accuracy: 0.6038 - val_loss: 0.7098 - val_accuracy: 0.5436 - lr: 0.0010
# Epoch 8/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6509 - accuracy: 0.6127
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 69s 1s/step - loss: 0.6509 - accuracy: 0.6127 - val_loss: 0.7188 - val_accuracy: 0.5282 - lr: 0.0010
# Epoch 9/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6479 - accuracy: 0.6217
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 53s 998ms/step - loss: 0.6479 - accuracy: 0.6217 - val_loss: 0.7941 - val_accuracy: 0.5590 - lr: 0.0010
# Epoch 10/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6275 - accuracy: 0.6382
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 53s 1s/step - loss: 0.6275 - accuracy: 0.6382 - val_loss: 0.7581 - val_accuracy: 0.5744 - lr: 0.0010
# Epoch 11/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6339 - accuracy: 0.6497
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 56s 1s/step - loss: 0.6339 - accuracy: 0.6497 - val_loss: 0.7175 - val_accuracy: 0.4872 - lr: 0.0010
# Epoch 12/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6311 - accuracy: 0.6599
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 55s 1s/step - loss: 0.6311 - accuracy: 0.6599 - val_loss: 0.6705 - val_accuracy: 0.5846 - lr: 0.0010
# Epoch 13/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6315 - accuracy: 0.6318
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 54s 1s/step - loss: 0.6315 - accuracy: 0.6318 - val_loss: 0.6998 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 14/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6321 - accuracy: 0.6318
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 56s 1s/step - loss: 0.6321 - accuracy: 0.6318 - val_loss: 0.7142 - val_accuracy: 0.5385 - lr: 0.0010
# Epoch 15/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6275 - accuracy: 0.6357
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 55s 1s/step - loss: 0.6275 - accuracy: 0.6357 - val_loss: 0.6727 - val_accuracy: 0.6308 - lr: 0.0010
# Epoch 16/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6206 - accuracy: 0.6471
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 56s 1s/step - loss: 0.6206 - accuracy: 0.6471 - val_loss: 0.6350 - val_accuracy: 0.6564 - lr: 0.0010
# Epoch 17/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6219 - accuracy: 0.6586
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 53s 991ms/step - loss: 0.6219 - accuracy: 0.6586 - val_loss: 0.7483 - val_accuracy: 0.5641 - lr: 0.0010
# Epoch 18/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6183 - accuracy: 0.6433
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 81s 2s/step - loss: 0.6183 - accuracy: 0.6433 - val_loss: 0.6619 - val_accuracy: 0.6103 - lr: 0.0010
# Epoch 19/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6102 - accuracy: 0.6650
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 53s 1000ms/step - loss: 0.6102 - accuracy: 0.6650 - val_loss: 0.7158 - val_accuracy: 0.5282 - lr: 0.0010
# Epoch 20/20
# 53/53 [==============================] - ETA: 0s - loss: 0.6134 - accuracy: 0.6522
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 53/53 [==============================] - 55s 1s/step - loss: 0.6134 - accuracy: 0.6522 - val_loss: 0.6638 - val_accuracy: 0.6000 - lr: 0.0010

# %% [markdown]
# # Save Model

# %%
model.save_weights("model.h5")

# %% [markdown]
# # Virtualize Training

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(history.history['loss'], color='b', label="Training loss")
ax1.plot(history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, epochs, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Prepare Testing Data

# %%
test_filenames = os.listdir("/content/drive/MyDrive/Data/CNN/testing")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]
nb_samples
# Out:
# 200

# %% [markdown]
# # Create Testing Generator

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df,
    "/content/drive/MyDrive/Data/CNN/testing",
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 200 validated image filenames.

# %% [markdown]
# # Predict

# %%
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))

# %% [markdown]
# For categoral classication the prediction will come with probability of each category. So we will pick the category that have the highest probability with numpy average max

# %%
test_df['category'] = np.argmax(predict, axis=-1)

# %% [markdown]
# We will convert the predict category back into our generator classes by using `train_generator.class_indices`. It is the classes that image generator map while converting data into computer vision

# %%
test_df['category']
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 195    1
# 196    1
# 197    1
# 198    0
# 199    1
# Name: category, Length: 200, dtype: int64

# %%
test_df['category'].value_counts()
# Out:
# 0    103
# 1     97
# Name: category, dtype: int64

# %%
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category'] = test_df['category'].replace(label_map)
test_df['category'].value_counts()
# Out:
# cat    103
# dog     97
# Name: category, dtype: int64

# %% [markdown]
# From our prepare data part. We map data with `{1: 'dog', 0: 'cat'}`. Now we will map the result back to dog is 1 and cat is 0

# %%
test_df['label'] = test_df['filename'].apply(lambda x : 'cat' if 'cat' in x else 'dog')

# %%
test_df
# Out:
#          filename category label
# 0    cat.4498.jpg      cat   cat
# 1    cat.4512.jpg      dog   cat
# 2    cat.4500.jpg      dog   cat
# 3    cat.4501.jpg      cat   cat
# 4    cat.4496.jpg      dog   cat
# ..            ...      ...   ...
# 195  dog.4955.jpg      dog   dog
# 196  dog.4906.jpg      dog   dog
# 197  dog.4930.jpg      dog   dog
# 198  dog.4909.jpg      cat   dog
# 199  dog.4929.jpg      dog   dog
#
# [200 rows x 3 columns]

# %%
test_df['label'].value_counts()
# Out:
# cat    100
# dog    100
# Name: label, dtype: int64

# %% [markdown]
# ### Virtaulize Result

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

CM = confusion_matrix(test_df['label'], test_df['category'])
print('Confusion Matrix is : \n', CM)
# Out:
# Confusion Matrix is :
#  [[57 43]
#  [46 54]]

# %%
# drawing confusion matrix
sns.heatmap(CM, center = True,cmap='Blues_r')
plt.show()
